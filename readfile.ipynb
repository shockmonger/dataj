# %%
import btk
from btk import *

# %%
# reader = btk.btkAcquisitionFileReader()
# reader.SetFilename()
# reader.Update()
# acq = reader.GetOutput()

# %%
import scipy, numpy
import pandas as pd

# %%
df = pd.DataFrame.from_csv('emg.csv')

# %%
df
# Out:
#             Trigno sensor 1: EMG 1 [Volts]  X [s].1  \
# X [s]
# 0.000000                               0.0  0.00000
# 0.000519                               0.0  0.00675
# 0.001038                               0.0  0.01350
# 0.001558                               0.0  0.02025
# 0.002077                               0.0  0.02700
# 0.002596                               0.0  0.03375
# 0.003115                               0.0  0.04050
# 0.003635                               0.0  0.04725
# 0.004154                               0.0  0.05400
# 0.004673                               0.0  0.06075
# 0.005192                               0.0  0.06750
# 0.005712                               0.0  0.07425
# 0.006231                               0.0  0.08100
# 0.006750                               0.0  0.08775
# 0.007269                               0.0  0.09450
# 0.007788                               0.0  0.10125
# 0.008308                               0.0  0.10800
# ...

# %%
cols = df.keys()
cols[]
# Out:
# Index([u'Trigno sensor 1: EMG 1 [Volts]', u'X [s].1',
#        u'Trigno sensor 1: ACC X 1 [g]', u'X [s].2',
#        u'Trigno sensor 1: ACC Y 1 [g]', u'X [s].3',
#        u'Trigno sensor 1: ACC Z 1 [g]', u'X [s].4',
#        u'Trigno sensor 2: EMG 2 [Volts]', u'X [s].5',
#        u'Trigno sensor 2: ACC X 2 [g]', u'X [s].6',
#        u'Trigno sensor 2: ACC Y 2 [g]', u'X [s].7',
#        u'Trigno sensor 2: ACC Z 2 [g]', u'X [s].8',
#        u'Trigno sensor 3: EMG 3 [Volts]', u'X [s].9',
#        u'Trigno sensor 3: ACC X 3 [g]', u'X [s].10',
#        u'Trigno sensor 3: ACC Y 3 [g]', u'X [s].11',
#        u'Trigno sensor 3: ACC Z 3 [g]', u'X [s].12',
#        u'Trigno sensor 4: EMG 4 [Volts]', u'X [s].13',
#        u'Trigno sensor 4: ACC X 4 [g]', u'X [s].14',
#        u'Trigno sensor 4: ACC Y 4 [g]', u'X [s].15',
#        u'Trigno sensor 4: ACC Z 4 [g]', u'X [s].16',
#        u'Trigno sensor 5: EMG 5 [Volts]', u'X [s].17',
#        u'Trigno sensor 5: ACC X 5 [g]', u'X [s].18',
# ...
