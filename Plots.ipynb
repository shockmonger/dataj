# %%
# %run djscript.py
# %matplotlib inline

# %%
x = 
def animate(i):
    line.set_ydata(np.sin(x + i/10.0))  # update the data
    return line,
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line,
ani = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init,
                              interval=25, blit=True)
plt.show()

# %%
f,a = plt.subplots()
for i in range(len(X1.keys())):
    a = plt.plot(X1.iloc[:,i])

# %%
df1.corr()
# Out:
#                                        Trigno sensor 1: EMG 1 [Volts]  \
# Trigno sensor 1: EMG 1 [Volts]                               1.000000
# X [s].1                                                     -0.001088
# Trigno sensor 1: ACC X 1 [g]                                -0.008085
# X [s].2                                                     -0.001088
# Trigno sensor 1: ACC Y 1 [g]                                 0.001902
# X [s].3                                                     -0.001088
# Trigno sensor 1: ACC Z 1 [g]                                -0.004000
# X [s].4                                                      0.000428
# Trigno sensor 2: EMG 2 [Volts]                              -0.000225
# X [s].5                                                     -0.001088
# Trigno sensor 2: ACC X 2 [g]                                -0.002580
# X [s].6                                                     -0.001088
# Trigno sensor 2: ACC Y 2 [g]                                 0.000855
# X [s].7                                                     -0.001088
# Trigno sensor 2: ACC Z 2 [g]                                 0.010222
# X [s].8                                                      0.000428
# Trigno sensor 3: EMG 3 [Volts]                               0.009498
# X [s].9                                                     -0.001088
# Trigno sensor 3: ACC X 3 [g]                                -0.002900
# X [s].10                                                    -0.001088
# Trigno sensor 3: ACC Y 3 [g]                                 0.001602
# X [s].11                                                    -0.001088
# Trigno sensor 3: ACC Z 3 [g]                                -0.003157
# X [s].12                                                     0.000428
# Trigno sensor 4: EMG 4 [Volts]                              -0.001166
# X [s].13                                                    -0.001088
# Trigno sensor 4: ACC X 4 [g]                                -0.003163
# X [s].14                                                    -0.001088
# Trigno sensor 4: ACC Y 4 [g]                                -0.005754
# X [s].15                                                    -0.001088
# Trigno sensor 4: ACC Z 4 [g]                                -0.002768
# X [s].16                                                     0.000428
# Trigno sensor 5: EMG 5 [Volts]                              -0.007895
# X [s].17                                                    -0.001088
# Trigno sensor 5: ACC X 5 [g]                                -0.008647
# X [s].18                                                    -0.001088
# Trigno sensor 5: ACC Y 5 [g]                                 0.004853
# X [s].19                                                    -0.001088
# Trigno sensor 5: ACC Z 5 [g]                                 0.002864
# X [s].20                                                     0.000428
# Trigno Mini sensor 8: EMG 8 [Volts]                         -0.002062
# X [s].21                                                    -0.001088
# Trigno Mini sensor 8: ACC X 8 [g]                            0.005422
# X [s].22                                                    -0.001088
# Trigno Mini sensor 8: ACC Y 8 [g]                            0.004760
# X [s].23                                                    -0.001088
# Trigno Mini sensor 8: ACC Z 8 [g]                            0.007320
# X [s].24                                                     0.000428
# Trigno Mini sensor 10: EMG 10 [Volts]                        0.005724
# X [s].25                                                    -0.001088
# Trigno Mini sensor 10: ACC X 10 [g]                         -0.000767
# X [s].26                                                    -0.001088
# Trigno Mini sensor 10: ACC Y 10 [g]                         -0.011386
# X [s].27                                                    -0.001088
# Trigno Mini sensor 10: ACC Z 10 [g]                          0.000443
#
#                                         X [s].1  Trigno sensor 1: ACC X 1 [g]  \
# Trigno sensor 1: EMG 1 [Volts]        -0.001088                     -0.008085
# X [s].1                                1.000000                     -0.204892
# Trigno sensor 1: ACC X 1 [g]          -0.204892                      1.000000
# X [s].2                                1.000000                     -0.204892
# Trigno sensor 1: ACC Y 1 [g]          -0.243707                     -0.566957
# X [s].3                                1.000000                     -0.204892
# Trigno sensor 1: ACC Z 1 [g]          -0.441000                      0.604927
# X [s].4                                1.000000                     -0.204891
# Trigno sensor 2: EMG 2 [Volts]        -0.002950                     -0.008042
# X [s].5                                1.000000                     -0.204892
# Trigno sensor 2: ACC X 2 [g]          -0.153731                     -0.075386
# X [s].6                                1.000000                     -0.204892
# Trigno sensor 2: ACC Y 2 [g]           0.271238                      0.054381
# X [s].7                                1.000000                     -0.204892
# Trigno sensor 2: ACC Z 2 [g]           0.003853                     -0.247306
# X [s].8                                1.000000                     -0.204891
# Trigno sensor 3: EMG 3 [Volts]         0.000869                      0.008257
# X [s].9                                1.000000                     -0.204892
# Trigno sensor 3: ACC X 3 [g]           0.110666                      0.224255
# X [s].10                               1.000000                     -0.204892
# Trigno sensor 3: ACC Y 3 [g]           0.145715                     -0.293268
# X [s].11                               1.000000                     -0.204892
# Trigno sensor 3: ACC Z 3 [g]           0.014134                      0.049772
# X [s].12                               1.000000                     -0.204891
# Trigno sensor 4: EMG 4 [Volts]        -0.000228                     -0.007112
# X [s].13                               1.000000                     -0.204892
# Trigno sensor 4: ACC X 4 [g]           0.112469                     -0.019150
# X [s].14                               1.000000                     -0.204892
# Trigno sensor 4: ACC Y 4 [g]          -0.374951                      0.030722
# X [s].15                               1.000000                     -0.204892
# Trigno sensor 4: ACC Z 4 [g]          -0.472347                      0.172730
# X [s].16                               1.000000                     -0.204891
# Trigno sensor 5: EMG 5 [Volts]        -0.016504                     -0.007601
# X [s].17                               1.000000                     -0.204892
# Trigno sensor 5: ACC X 5 [g]           0.061628                      0.110879
# X [s].18                               1.000000                     -0.204892
# Trigno sensor 5: ACC Y 5 [g]          -0.249026                      0.339707
# X [s].19                               1.000000                     -0.204892
# Trigno sensor 5: ACC Z 5 [g]           0.109085                     -0.255374
# X [s].20                               1.000000                     -0.204891
# Trigno Mini sensor 8: EMG 8 [Volts]   -0.039364                     -0.010383
# X [s].21                               1.000000                     -0.204892
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965                     -0.153657
# X [s].22                               1.000000                     -0.204892
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210                     -0.278997
# X [s].23                               1.000000                     -0.204892
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816                      0.227808
# X [s].24                               1.000000                     -0.204891
# Trigno Mini sensor 10: EMG 10 [Volts] -0.009773                     -0.002491
# X [s].25                               1.000000                     -0.204892
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475                      0.127477
# X [s].26                               1.000000                     -0.204892
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078677                      0.128498
# X [s].27                               1.000000                     -0.204892
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014                      0.102325
#
#                                         X [s].2  Trigno sensor 1: ACC Y 1 [g]  \
# Trigno sensor 1: EMG 1 [Volts]        -0.001088                      0.001902
# X [s].1                                1.000000                     -0.243707
# Trigno sensor 1: ACC X 1 [g]          -0.204892                     -0.566957
# X [s].2                                1.000000                     -0.243707
# Trigno sensor 1: ACC Y 1 [g]          -0.243707                      1.000000
# X [s].3                                1.000000                     -0.243707
# Trigno sensor 1: ACC Z 1 [g]          -0.441000                     -0.247166
# X [s].4                                1.000000                     -0.243707
# Trigno sensor 2: EMG 2 [Volts]        -0.002950                      0.003805
# X [s].5                                1.000000                     -0.243707
# Trigno sensor 2: ACC X 2 [g]          -0.153731                      0.005756
# X [s].6                                1.000000                     -0.243707
# Trigno sensor 2: ACC Y 2 [g]           0.271238                     -0.098812
# X [s].7                                1.000000                     -0.243707
# Trigno sensor 2: ACC Z 2 [g]           0.003853                     -0.057877
# X [s].8                                1.000000                     -0.243707
# Trigno sensor 3: EMG 3 [Volts]         0.000869                     -0.002052
# X [s].9                                1.000000                     -0.243707
# Trigno sensor 3: ACC X 3 [g]           0.110666                     -0.371910
# X [s].10                               1.000000                     -0.243707
# Trigno sensor 3: ACC Y 3 [g]           0.145715                      0.246803
# X [s].11                               1.000000                     -0.243707
# Trigno sensor 3: ACC Z 3 [g]           0.014134                     -0.194083
# X [s].12                               1.000000                     -0.243707
# Trigno sensor 4: EMG 4 [Volts]        -0.000228                      0.006005
# X [s].13                               1.000000                     -0.243707
# Trigno sensor 4: ACC X 4 [g]           0.112469                     -0.004187
# X [s].14                               1.000000                     -0.243707
# Trigno sensor 4: ACC Y 4 [g]          -0.374951                      0.057480
# X [s].15                               1.000000                     -0.243707
# Trigno sensor 4: ACC Z 4 [g]          -0.472347                      0.014818
# X [s].16                               1.000000                     -0.243707
# Trigno sensor 5: EMG 5 [Volts]        -0.016504                      0.004789
# X [s].17                               1.000000                     -0.243707
# Trigno sensor 5: ACC X 5 [g]           0.061628                      0.089481
# X [s].18                               1.000000                     -0.243707
# Trigno sensor 5: ACC Y 5 [g]          -0.249026                     -0.118585
# X [s].19                               1.000000                     -0.243707
# Trigno sensor 5: ACC Z 5 [g]           0.109085                      0.243712
# X [s].20                               1.000000                     -0.243707
# Trigno Mini sensor 8: EMG 8 [Volts]   -0.039364                      0.013239
# X [s].21                               1.000000                     -0.243707
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965                      0.026329
# X [s].22                               1.000000                     -0.243707
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210                     -0.026870
# X [s].23                               1.000000                     -0.243707
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816                      0.067998
# X [s].24                               1.000000                     -0.243707
# Trigno Mini sensor 10: EMG 10 [Volts] -0.009773                      0.002839
# X [s].25                               1.000000                     -0.243707
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475                      0.212376
# X [s].26                               1.000000                     -0.243707
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078677                      0.137286
# X [s].27                               1.000000                     -0.243707
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014                      0.215604
#
#                                         X [s].3  Trigno sensor 1: ACC Z 1 [g]  \
# Trigno sensor 1: EMG 1 [Volts]        -0.001088                     -0.004000
# X [s].1                                1.000000                     -0.441000
# Trigno sensor 1: ACC X 1 [g]          -0.204892                      0.604927
# X [s].2                                1.000000                     -0.441000
# Trigno sensor 1: ACC Y 1 [g]          -0.243707                     -0.247166
# X [s].3                                1.000000                     -0.441000
# Trigno sensor 1: ACC Z 1 [g]          -0.441000                      1.000000
# X [s].4                                1.000000                     -0.441000
# Trigno sensor 2: EMG 2 [Volts]        -0.002950                      0.003158
# X [s].5                                1.000000                     -0.441000
# Trigno sensor 2: ACC X 2 [g]          -0.153731                      0.010185
# X [s].6                                1.000000                     -0.441000
# Trigno sensor 2: ACC Y 2 [g]           0.271238                     -0.159401
# X [s].7                                1.000000                     -0.441000
# Trigno sensor 2: ACC Z 2 [g]           0.003853                     -0.132840
# X [s].8                                1.000000                     -0.441000
# Trigno sensor 3: EMG 3 [Volts]         0.000869                      0.004853
# X [s].9                                1.000000                     -0.441000
# Trigno sensor 3: ACC X 3 [g]           0.110666                      0.094477
# X [s].10                               1.000000                     -0.441000
# Trigno sensor 3: ACC Y 3 [g]           0.145715                     -0.006978
# X [s].11                               1.000000                     -0.441000
# Trigno sensor 3: ACC Z 3 [g]           0.014134                      0.108399
# X [s].12                               1.000000                     -0.441000
# Trigno sensor 4: EMG 4 [Volts]        -0.000228                     -0.051918
# X [s].13                               1.000000                     -0.441000
# Trigno sensor 4: ACC X 4 [g]           0.112469                      0.129678
# X [s].14                               1.000000                     -0.441000
# Trigno sensor 4: ACC Y 4 [g]          -0.374951                     -0.060957
# X [s].15                               1.000000                     -0.441000
# Trigno sensor 4: ACC Z 4 [g]          -0.472347                      0.203165
# X [s].16                               1.000000                     -0.441000
# Trigno sensor 5: EMG 5 [Volts]        -0.016504                     -0.001475
# X [s].17                               1.000000                     -0.441000
# Trigno sensor 5: ACC X 5 [g]           0.061628                      0.052716
# X [s].18                               1.000000                     -0.441000
# Trigno sensor 5: ACC Y 5 [g]          -0.249026                      0.510140
# X [s].19                               1.000000                     -0.441000
# Trigno sensor 5: ACC Z 5 [g]           0.109085                     -0.190473
# X [s].20                               1.000000                     -0.441000
# Trigno Mini sensor 8: EMG 8 [Volts]   -0.039364                     -0.015084
# X [s].21                               1.000000                     -0.441000
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965                     -0.069477
# X [s].22                               1.000000                     -0.441000
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210                     -0.232546
# X [s].23                               1.000000                     -0.441000
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816                      0.243264
# X [s].24                               1.000000                     -0.441000
# Trigno Mini sensor 10: EMG 10 [Volts] -0.009773                     -0.000325
# X [s].25                               1.000000                     -0.441000
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475                      0.227010
# X [s].26                               1.000000                     -0.441000
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078677                      0.142999
# X [s].27                               1.000000                     -0.441000
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014                      0.340382
#
#                                         X [s].4  \
# Trigno sensor 1: EMG 1 [Volts]         0.000428
# X [s].1                                1.000000
# Trigno sensor 1: ACC X 1 [g]          -0.204891
# X [s].2                                1.000000
# Trigno sensor 1: ACC Y 1 [g]          -0.243707
# X [s].3                                1.000000
# Trigno sensor 1: ACC Z 1 [g]          -0.441000
# X [s].4                                1.000000
# Trigno sensor 2: EMG 2 [Volts]        -0.001854
# X [s].5                                1.000000
# Trigno sensor 2: ACC X 2 [g]          -0.153731
# X [s].6                                1.000000
# Trigno sensor 2: ACC Y 2 [g]           0.271238
# X [s].7                                1.000000
# Trigno sensor 2: ACC Z 2 [g]           0.003853
# X [s].8                                1.000000
# Trigno sensor 3: EMG 3 [Volts]         0.004835
# X [s].9                                1.000000
# Trigno sensor 3: ACC X 3 [g]           0.110666
# X [s].10                               1.000000
# Trigno sensor 3: ACC Y 3 [g]           0.145715
# X [s].11                               1.000000
# Trigno sensor 3: ACC Z 3 [g]           0.014134
# X [s].12                               1.000000
# Trigno sensor 4: EMG 4 [Volts]         0.000463
# X [s].13                               1.000000
# Trigno sensor 4: ACC X 4 [g]           0.112469
# X [s].14                               1.000000
# Trigno sensor 4: ACC Y 4 [g]          -0.374950
# X [s].15                               1.000000
# Trigno sensor 4: ACC Z 4 [g]          -0.472346
# X [s].16                               1.000000
# Trigno sensor 5: EMG 5 [Volts]         0.001799
# X [s].17                               1.000000
# Trigno sensor 5: ACC X 5 [g]           0.061628
# X [s].18                               1.000000
# Trigno sensor 5: ACC Y 5 [g]          -0.249026
# X [s].19                               1.000000
# Trigno sensor 5: ACC Z 5 [g]           0.109085
# X [s].20                               1.000000
# Trigno Mini sensor 8: EMG 8 [Volts]    0.003491
# X [s].21                               1.000000
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965
# X [s].22                               1.000000
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210
# X [s].23                               1.000000
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816
# X [s].24                               1.000000
# Trigno Mini sensor 10: EMG 10 [Volts] -0.006127
# X [s].25                               1.000000
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475
# X [s].26                               1.000000
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078678
# X [s].27                               1.000000
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014
#
#                                        Trigno sensor 2: EMG 2 [Volts]  \
# Trigno sensor 1: EMG 1 [Volts]                              -0.000225
# X [s].1                                                     -0.002950
# Trigno sensor 1: ACC X 1 [g]                                -0.008042
# X [s].2                                                     -0.002950
# Trigno sensor 1: ACC Y 1 [g]                                 0.003805
# X [s].3                                                     -0.002950
# Trigno sensor 1: ACC Z 1 [g]                                 0.003158
# X [s].4                                                     -0.001854
# Trigno sensor 2: EMG 2 [Volts]                               1.000000
# X [s].5                                                     -0.002950
# Trigno sensor 2: ACC X 2 [g]                                 0.005183
# X [s].6                                                     -0.002950
# Trigno sensor 2: ACC Y 2 [g]                                -0.004716
# X [s].7                                                     -0.002950
# Trigno sensor 2: ACC Z 2 [g]                                 0.005924
# X [s].8                                                     -0.001854
# Trigno sensor 3: EMG 3 [Volts]                              -0.000431
# X [s].9                                                     -0.002950
# Trigno sensor 3: ACC X 3 [g]                                 0.000532
# X [s].10                                                    -0.002950
# Trigno sensor 3: ACC Y 3 [g]                                 0.001430
# X [s].11                                                    -0.002950
# Trigno sensor 3: ACC Z 3 [g]                                -0.001683
# X [s].12                                                    -0.001854
# Trigno sensor 4: EMG 4 [Volts]                               0.007609
# X [s].13                                                    -0.002950
# Trigno sensor 4: ACC X 4 [g]                                 0.002374
# X [s].14                                                    -0.002950
# Trigno sensor 4: ACC Y 4 [g]                                 0.004754
# X [s].15                                                    -0.002950
# Trigno sensor 4: ACC Z 4 [g]                                 0.000180
# X [s].16                                                    -0.001854
# Trigno sensor 5: EMG 5 [Volts]                               0.009986
# X [s].17                                                    -0.002950
# Trigno sensor 5: ACC X 5 [g]                                 0.002338
# X [s].18                                                    -0.002950
# Trigno sensor 5: ACC Y 5 [g]                                -0.000326
# X [s].19                                                    -0.002950
# Trigno sensor 5: ACC Z 5 [g]                                 0.009311
# X [s].20                                                    -0.001854
# Trigno Mini sensor 8: EMG 8 [Volts]                          0.011698
# X [s].21                                                    -0.002950
# Trigno Mini sensor 8: ACC X 8 [g]                           -0.000545
# X [s].22                                                    -0.002950
# Trigno Mini sensor 8: ACC Y 8 [g]                           -0.003062
# X [s].23                                                    -0.002950
# Trigno Mini sensor 8: ACC Z 8 [g]                            0.002220
# X [s].24                                                    -0.001854
# Trigno Mini sensor 10: EMG 10 [Volts]                        0.013050
# X [s].25                                                    -0.002950
# Trigno Mini sensor 10: ACC X 10 [g]                          0.001809
# X [s].26                                                    -0.002950
# Trigno Mini sensor 10: ACC Y 10 [g]                          0.005499
# X [s].27                                                    -0.002950
# Trigno Mini sensor 10: ACC Z 10 [g]                          0.000245
#
#                                         X [s].5  \
# Trigno sensor 1: EMG 1 [Volts]        -0.001088
# X [s].1                                1.000000
# Trigno sensor 1: ACC X 1 [g]          -0.204892
# X [s].2                                1.000000
# Trigno sensor 1: ACC Y 1 [g]          -0.243707
# X [s].3                                1.000000
# Trigno sensor 1: ACC Z 1 [g]          -0.441000
# X [s].4                                1.000000
# Trigno sensor 2: EMG 2 [Volts]        -0.002950
# X [s].5                                1.000000
# Trigno sensor 2: ACC X 2 [g]          -0.153731
# X [s].6                                1.000000
# Trigno sensor 2: ACC Y 2 [g]           0.271238
# X [s].7                                1.000000
# Trigno sensor 2: ACC Z 2 [g]           0.003853
# X [s].8                                1.000000
# Trigno sensor 3: EMG 3 [Volts]         0.000869
# X [s].9                                1.000000
# Trigno sensor 3: ACC X 3 [g]           0.110666
# X [s].10                               1.000000
# Trigno sensor 3: ACC Y 3 [g]           0.145715
# X [s].11                               1.000000
# Trigno sensor 3: ACC Z 3 [g]           0.014134
# X [s].12                               1.000000
# Trigno sensor 4: EMG 4 [Volts]        -0.000228
# X [s].13                               1.000000
# Trigno sensor 4: ACC X 4 [g]           0.112469
# X [s].14                               1.000000
# Trigno sensor 4: ACC Y 4 [g]          -0.374951
# X [s].15                               1.000000
# Trigno sensor 4: ACC Z 4 [g]          -0.472347
# X [s].16                               1.000000
# Trigno sensor 5: EMG 5 [Volts]        -0.016504
# X [s].17                               1.000000
# Trigno sensor 5: ACC X 5 [g]           0.061628
# X [s].18                               1.000000
# Trigno sensor 5: ACC Y 5 [g]          -0.249026
# X [s].19                               1.000000
# Trigno sensor 5: ACC Z 5 [g]           0.109085
# X [s].20                               1.000000
# Trigno Mini sensor 8: EMG 8 [Volts]   -0.039364
# X [s].21                               1.000000
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965
# X [s].22                               1.000000
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210
# X [s].23                               1.000000
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816
# X [s].24                               1.000000
# Trigno Mini sensor 10: EMG 10 [Volts] -0.009773
# X [s].25                               1.000000
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475
# X [s].26                               1.000000
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078677
# X [s].27                               1.000000
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014
#
#                                                       ...                   \
# Trigno sensor 1: EMG 1 [Volts]                        ...
# X [s].1                                               ...
# Trigno sensor 1: ACC X 1 [g]                          ...
# X [s].2                                               ...
# Trigno sensor 1: ACC Y 1 [g]                          ...
# X [s].3                                               ...
# Trigno sensor 1: ACC Z 1 [g]                          ...
# X [s].4                                               ...
# Trigno sensor 2: EMG 2 [Volts]                        ...
# X [s].5                                               ...
# Trigno sensor 2: ACC X 2 [g]                          ...
# X [s].6                                               ...
# Trigno sensor 2: ACC Y 2 [g]                          ...
# X [s].7                                               ...
# Trigno sensor 2: ACC Z 2 [g]                          ...
# X [s].8                                               ...
# Trigno sensor 3: EMG 3 [Volts]                        ...
# X [s].9                                               ...
# Trigno sensor 3: ACC X 3 [g]                          ...
# X [s].10                                              ...
# Trigno sensor 3: ACC Y 3 [g]                          ...
# X [s].11                                              ...
# Trigno sensor 3: ACC Z 3 [g]                          ...
# X [s].12                                              ...
# Trigno sensor 4: EMG 4 [Volts]                        ...
# X [s].13                                              ...
# Trigno sensor 4: ACC X 4 [g]                          ...
# X [s].14                                              ...
# Trigno sensor 4: ACC Y 4 [g]                          ...
# X [s].15                                              ...
# Trigno sensor 4: ACC Z 4 [g]                          ...
# X [s].16                                              ...
# Trigno sensor 5: EMG 5 [Volts]                        ...
# X [s].17                                              ...
# Trigno sensor 5: ACC X 5 [g]                          ...
# X [s].18                                              ...
# Trigno sensor 5: ACC Y 5 [g]                          ...
# X [s].19                                              ...
# Trigno sensor 5: ACC Z 5 [g]                          ...
# X [s].20                                              ...
# Trigno Mini sensor 8: EMG 8 [Volts]                   ...
# X [s].21                                              ...
# Trigno Mini sensor 8: ACC X 8 [g]                     ...
# X [s].22                                              ...
# Trigno Mini sensor 8: ACC Y 8 [g]                     ...
# X [s].23                                              ...
# Trigno Mini sensor 8: ACC Z 8 [g]                     ...
# X [s].24                                              ...
# Trigno Mini sensor 10: EMG 10 [Volts]                 ...
# X [s].25                                              ...
# Trigno Mini sensor 10: ACC X 10 [g]                   ...
# X [s].26                                              ...
# Trigno Mini sensor 10: ACC Y 10 [g]                   ...
# X [s].27                                              ...
# Trigno Mini sensor 10: ACC Z 10 [g]                   ...
#
#                                        X [s].23  \
# Trigno sensor 1: EMG 1 [Volts]        -0.001088
# X [s].1                                1.000000
# Trigno sensor 1: ACC X 1 [g]          -0.204892
# X [s].2                                1.000000
# Trigno sensor 1: ACC Y 1 [g]          -0.243707
# X [s].3                                1.000000
# Trigno sensor 1: ACC Z 1 [g]          -0.441000
# X [s].4                                1.000000
# Trigno sensor 2: EMG 2 [Volts]        -0.002950
# X [s].5                                1.000000
# Trigno sensor 2: ACC X 2 [g]          -0.153731
# X [s].6                                1.000000
# Trigno sensor 2: ACC Y 2 [g]           0.271238
# X [s].7                                1.000000
# Trigno sensor 2: ACC Z 2 [g]           0.003853
# X [s].8                                1.000000
# Trigno sensor 3: EMG 3 [Volts]         0.000869
# X [s].9                                1.000000
# Trigno sensor 3: ACC X 3 [g]           0.110666
# X [s].10                               1.000000
# Trigno sensor 3: ACC Y 3 [g]           0.145715
# X [s].11                               1.000000
# Trigno sensor 3: ACC Z 3 [g]           0.014134
# X [s].12                               1.000000
# Trigno sensor 4: EMG 4 [Volts]        -0.000228
# X [s].13                               1.000000
# Trigno sensor 4: ACC X 4 [g]           0.112469
# X [s].14                               1.000000
# Trigno sensor 4: ACC Y 4 [g]          -0.374951
# X [s].15                               1.000000
# Trigno sensor 4: ACC Z 4 [g]          -0.472347
# X [s].16                               1.000000
# Trigno sensor 5: EMG 5 [Volts]        -0.016504
# X [s].17                               1.000000
# Trigno sensor 5: ACC X 5 [g]           0.061628
# X [s].18                               1.000000
# Trigno sensor 5: ACC Y 5 [g]          -0.249026
# X [s].19                               1.000000
# Trigno sensor 5: ACC Z 5 [g]           0.109085
# X [s].20                               1.000000
# Trigno Mini sensor 8: EMG 8 [Volts]   -0.039364
# X [s].21                               1.000000
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965
# X [s].22                               1.000000
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210
# X [s].23                               1.000000
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816
# X [s].24                               1.000000
# Trigno Mini sensor 10: EMG 10 [Volts] -0.009773
# X [s].25                               1.000000
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475
# X [s].26                               1.000000
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078677
# X [s].27                               1.000000
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014
#
#                                        Trigno Mini sensor 8: ACC Z 8 [g]  \
# Trigno sensor 1: EMG 1 [Volts]                                  0.007320
# X [s].1                                                        -0.485816
# Trigno sensor 1: ACC X 1 [g]                                    0.227808
# X [s].2                                                        -0.485816
# Trigno sensor 1: ACC Y 1 [g]                                    0.067998
# X [s].3                                                        -0.485816
# Trigno sensor 1: ACC Z 1 [g]                                    0.243264
# X [s].4                                                        -0.485816
# Trigno sensor 2: EMG 2 [Volts]                                  0.002220
# X [s].5                                                        -0.485816
# Trigno sensor 2: ACC X 2 [g]                                   -0.191533
# X [s].6                                                        -0.485816
# Trigno sensor 2: ACC Y 2 [g]                                   -0.013485
# X [s].7                                                        -0.485816
# Trigno sensor 2: ACC Z 2 [g]                                   -0.304652
# X [s].8                                                        -0.485816
# Trigno sensor 3: EMG 3 [Volts]                                  0.000023
# X [s].9                                                        -0.485816
# Trigno sensor 3: ACC X 3 [g]                                    0.067912
# X [s].10                                                       -0.485816
# Trigno sensor 3: ACC Y 3 [g]                                   -0.490245
# X [s].11                                                       -0.485816
# Trigno sensor 3: ACC Z 3 [g]                                   -0.128736
# X [s].12                                                       -0.485816
# Trigno sensor 4: EMG 4 [Volts]                                 -0.000461
# X [s].13                                                       -0.485816
# Trigno sensor 4: ACC X 4 [g]                                   -0.184594
# X [s].14                                                       -0.485816
# Trigno sensor 4: ACC Y 4 [g]                                    0.148787
# X [s].15                                                       -0.485816
# Trigno sensor 4: ACC Z 4 [g]                                    0.309005
# X [s].16                                                       -0.485816
# Trigno sensor 5: EMG 5 [Volts]                                  0.002042
# X [s].17                                                       -0.485816
# Trigno sensor 5: ACC X 5 [g]                                   -0.097273
# X [s].18                                                       -0.485816
# Trigno sensor 5: ACC Y 5 [g]                                    0.188378
# X [s].19                                                       -0.485816
# Trigno sensor 5: ACC Z 5 [g]                                   -0.095187
# X [s].20                                                       -0.485816
# Trigno Mini sensor 8: EMG 8 [Volts]                            -0.019586
# X [s].21                                                       -0.485816
# Trigno Mini sensor 8: ACC X 8 [g]                              -0.689251
# X [s].22                                                       -0.485816
# Trigno Mini sensor 8: ACC Y 8 [g]                              -0.938850
# X [s].23                                                       -0.485816
# Trigno Mini sensor 8: ACC Z 8 [g]                               1.000000
# X [s].24                                                       -0.485816
# Trigno Mini sensor 10: EMG 10 [Volts]                          -0.008143
# X [s].25                                                       -0.485816
# Trigno Mini sensor 10: ACC X 10 [g]                             0.340035
# X [s].26                                                       -0.485816
# Trigno Mini sensor 10: ACC Y 10 [g]                             0.048322
# X [s].27                                                       -0.485816
# Trigno Mini sensor 10: ACC Z 10 [g]                             0.020279
#
#                                        X [s].24  \
# Trigno sensor 1: EMG 1 [Volts]         0.000428
# X [s].1                                1.000000
# Trigno sensor 1: ACC X 1 [g]          -0.204891
# X [s].2                                1.000000
# Trigno sensor 1: ACC Y 1 [g]          -0.243707
# X [s].3                                1.000000
# Trigno sensor 1: ACC Z 1 [g]          -0.441000
# X [s].4                                1.000000
# Trigno sensor 2: EMG 2 [Volts]        -0.001854
# X [s].5                                1.000000
# Trigno sensor 2: ACC X 2 [g]          -0.153731
# X [s].6                                1.000000
# Trigno sensor 2: ACC Y 2 [g]           0.271238
# X [s].7                                1.000000
# Trigno sensor 2: ACC Z 2 [g]           0.003853
# X [s].8                                1.000000
# Trigno sensor 3: EMG 3 [Volts]         0.004835
# X [s].9                                1.000000
# Trigno sensor 3: ACC X 3 [g]           0.110666
# X [s].10                               1.000000
# Trigno sensor 3: ACC Y 3 [g]           0.145715
# X [s].11                               1.000000
# Trigno sensor 3: ACC Z 3 [g]           0.014134
# X [s].12                               1.000000
# Trigno sensor 4: EMG 4 [Volts]         0.000463
# X [s].13                               1.000000
# Trigno sensor 4: ACC X 4 [g]           0.112469
# X [s].14                               1.000000
# Trigno sensor 4: ACC Y 4 [g]          -0.374950
# X [s].15                               1.000000
# Trigno sensor 4: ACC Z 4 [g]          -0.472346
# X [s].16                               1.000000
# Trigno sensor 5: EMG 5 [Volts]         0.001799
# X [s].17                               1.000000
# Trigno sensor 5: ACC X 5 [g]           0.061628
# X [s].18                               1.000000
# Trigno sensor 5: ACC Y 5 [g]          -0.249026
# X [s].19                               1.000000
# Trigno sensor 5: ACC Z 5 [g]           0.109085
# X [s].20                               1.000000
# Trigno Mini sensor 8: EMG 8 [Volts]    0.003491
# X [s].21                               1.000000
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965
# X [s].22                               1.000000
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210
# X [s].23                               1.000000
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816
# X [s].24                               1.000000
# Trigno Mini sensor 10: EMG 10 [Volts] -0.006127
# X [s].25                               1.000000
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475
# X [s].26                               1.000000
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078678
# X [s].27                               1.000000
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014
#
#                                        Trigno Mini sensor 10: EMG 10 [Volts]  \
# Trigno sensor 1: EMG 1 [Volts]                                      0.005724
# X [s].1                                                            -0.009773
# Trigno sensor 1: ACC X 1 [g]                                       -0.002491
# X [s].2                                                            -0.009773
# Trigno sensor 1: ACC Y 1 [g]                                        0.002839
# X [s].3                                                            -0.009773
# Trigno sensor 1: ACC Z 1 [g]                                       -0.000325
# X [s].4                                                            -0.006127
# Trigno sensor 2: EMG 2 [Volts]                                      0.013050
# X [s].5                                                            -0.009773
# Trigno sensor 2: ACC X 2 [g]                                        0.008498
# X [s].6                                                            -0.009773
# Trigno sensor 2: ACC Y 2 [g]                                       -0.001209
# X [s].7                                                            -0.009773
# Trigno sensor 2: ACC Z 2 [g]                                        0.010041
# X [s].8                                                            -0.006127
# Trigno sensor 3: EMG 3 [Volts]                                     -0.009990
# X [s].9                                                            -0.009773
# Trigno sensor 3: ACC X 3 [g]                                        0.001237
# X [s].10                                                           -0.009773
# Trigno sensor 3: ACC Y 3 [g]                                       -0.002849
# X [s].11                                                           -0.009773
# Trigno sensor 3: ACC Z 3 [g]                                       -0.000846
# X [s].12                                                           -0.006127
# Trigno sensor 4: EMG 4 [Volts]                                     -0.004042
# X [s].13                                                           -0.009773
# Trigno sensor 4: ACC X 4 [g]                                        0.004226
# X [s].14                                                           -0.009773
# Trigno sensor 4: ACC Y 4 [g]                                        0.003737
# X [s].15                                                           -0.009773
# Trigno sensor 4: ACC Z 4 [g]                                       -0.002035
# X [s].16                                                           -0.006127
# Trigno sensor 5: EMG 5 [Volts]                                      0.010064
# X [s].17                                                           -0.009773
# Trigno sensor 5: ACC X 5 [g]                                       -0.002466
# X [s].18                                                           -0.009773
# Trigno sensor 5: ACC Y 5 [g]                                        0.000752
# X [s].19                                                           -0.009773
# Trigno sensor 5: ACC Z 5 [g]                                       -0.001283
# X [s].20                                                           -0.006127
# Trigno Mini sensor 8: EMG 8 [Volts]                                 0.004581
# X [s].21                                                           -0.009773
# Trigno Mini sensor 8: ACC X 8 [g]                                   0.007456
# X [s].22                                                           -0.009773
# Trigno Mini sensor 8: ACC Y 8 [g]                                   0.006170
# X [s].23                                                           -0.009773
# Trigno Mini sensor 8: ACC Z 8 [g]                                  -0.008143
# X [s].24                                                           -0.006127
# Trigno Mini sensor 10: EMG 10 [Volts]                               1.000000
# X [s].25                                                           -0.009773
# Trigno Mini sensor 10: ACC X 10 [g]                                -0.003643
# X [s].26                                                           -0.009773
# Trigno Mini sensor 10: ACC Y 10 [g]                                -0.000251
# X [s].27                                                           -0.009773
# Trigno Mini sensor 10: ACC Z 10 [g]                                 0.003301
#
#                                        X [s].25  \
# Trigno sensor 1: EMG 1 [Volts]        -0.001088
# X [s].1                                1.000000
# Trigno sensor 1: ACC X 1 [g]          -0.204892
# X [s].2                                1.000000
# Trigno sensor 1: ACC Y 1 [g]          -0.243707
# X [s].3                                1.000000
# Trigno sensor 1: ACC Z 1 [g]          -0.441000
# X [s].4                                1.000000
# Trigno sensor 2: EMG 2 [Volts]        -0.002950
# X [s].5                                1.000000
# Trigno sensor 2: ACC X 2 [g]          -0.153731
# X [s].6                                1.000000
# Trigno sensor 2: ACC Y 2 [g]           0.271238
# X [s].7                                1.000000
# Trigno sensor 2: ACC Z 2 [g]           0.003853
# X [s].8                                1.000000
# Trigno sensor 3: EMG 3 [Volts]         0.000869
# X [s].9                                1.000000
# Trigno sensor 3: ACC X 3 [g]           0.110666
# X [s].10                               1.000000
# Trigno sensor 3: ACC Y 3 [g]           0.145715
# X [s].11                               1.000000
# Trigno sensor 3: ACC Z 3 [g]           0.014134
# X [s].12                               1.000000
# Trigno sensor 4: EMG 4 [Volts]        -0.000228
# X [s].13                               1.000000
# Trigno sensor 4: ACC X 4 [g]           0.112469
# X [s].14                               1.000000
# Trigno sensor 4: ACC Y 4 [g]          -0.374951
# X [s].15                               1.000000
# Trigno sensor 4: ACC Z 4 [g]          -0.472347
# ...
# X [s].18                                                         -0.434475
# Trigno sensor 5: ACC Y 5 [g]                                      0.238307
# X [s].19                                                         -0.434475
# Trigno sensor 5: ACC Z 5 [g]                                     -0.137038
# X [s].20                                                         -0.434475
# Trigno Mini sensor 8: EMG 8 [Volts]                               0.000744
# X [s].21                                                         -0.434475
# Trigno Mini sensor 8: ACC X 8 [g]                                -0.183117
# X [s].22                                                         -0.434475
# Trigno Mini sensor 8: ACC Y 8 [g]                                -0.327006
# X [s].23                                                         -0.434475
# Trigno Mini sensor 8: ACC Z 8 [g]                                 0.340035
# X [s].24                                                         -0.434475
# Trigno Mini sensor 10: EMG 10 [Volts]                            -0.003643
# X [s].25                                                         -0.434475
# Trigno Mini sensor 10: ACC X 10 [g]                               1.000000
# X [s].26                                                         -0.434475
# Trigno Mini sensor 10: ACC Y 10 [g]                               0.656425
# X [s].27                                                         -0.434475
# Trigno Mini sensor 10: ACC Z 10 [g]                               0.676629
#
#                                        X [s].26  \
# Trigno sensor 1: EMG 1 [Volts]        -0.001088
# X [s].1                                1.000000
# Trigno sensor 1: ACC X 1 [g]          -0.204892
# X [s].2                                1.000000
# Trigno sensor 1: ACC Y 1 [g]          -0.243707
# X [s].3                                1.000000
# Trigno sensor 1: ACC Z 1 [g]          -0.441000
# X [s].4                                1.000000
# Trigno sensor 2: EMG 2 [Volts]        -0.002950
# X [s].5                                1.000000
# Trigno sensor 2: ACC X 2 [g]          -0.153731
# X [s].6                                1.000000
# Trigno sensor 2: ACC Y 2 [g]           0.271238
# X [s].7                                1.000000
# Trigno sensor 2: ACC Z 2 [g]           0.003853
# X [s].8                                1.000000
# Trigno sensor 3: EMG 3 [Volts]         0.000869
# X [s].9                                1.000000
# Trigno sensor 3: ACC X 3 [g]           0.110666
# X [s].10                               1.000000
# Trigno sensor 3: ACC Y 3 [g]           0.145715
# X [s].11                               1.000000
# Trigno sensor 3: ACC Z 3 [g]           0.014134
# X [s].12                               1.000000
# Trigno sensor 4: EMG 4 [Volts]        -0.000228
# X [s].13                               1.000000
# Trigno sensor 4: ACC X 4 [g]           0.112469
# X [s].14                               1.000000
# Trigno sensor 4: ACC Y 4 [g]          -0.374951
# X [s].15                               1.000000
# Trigno sensor 4: ACC Z 4 [g]          -0.472347
# X [s].16                               1.000000
# Trigno sensor 5: EMG 5 [Volts]        -0.016504
# X [s].17                               1.000000
# Trigno sensor 5: ACC X 5 [g]           0.061628
# X [s].18                               1.000000
# Trigno sensor 5: ACC Y 5 [g]          -0.249026
# X [s].19                               1.000000
# Trigno sensor 5: ACC Z 5 [g]           0.109085
# X [s].20                               1.000000
# Trigno Mini sensor 8: EMG 8 [Volts]   -0.039364
# X [s].21                               1.000000
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965
# X [s].22                               1.000000
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210
# X [s].23                               1.000000
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816
# X [s].24                               1.000000
# Trigno Mini sensor 10: EMG 10 [Volts] -0.009773
# X [s].25                               1.000000
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475
# X [s].26                               1.000000
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078677
# X [s].27                               1.000000
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014
#
#                                        Trigno Mini sensor 10: ACC Y 10 [g]  \
# Trigno sensor 1: EMG 1 [Volts]                                   -0.011386
# X [s].1                                                          -0.078677
# Trigno sensor 1: ACC X 1 [g]                                      0.128498
# X [s].2                                                          -0.078677
# Trigno sensor 1: ACC Y 1 [g]                                      0.137286
# X [s].3                                                          -0.078677
# Trigno sensor 1: ACC Z 1 [g]                                      0.142999
# X [s].4                                                          -0.078678
# Trigno sensor 2: EMG 2 [Volts]                                    0.005499
# X [s].5                                                          -0.078677
# Trigno sensor 2: ACC X 2 [g]                                      0.118836
# X [s].6                                                          -0.078677
# Trigno sensor 2: ACC Y 2 [g]                                     -0.078397
# X [s].7                                                          -0.078677
# Trigno sensor 2: ACC Z 2 [g]                                     -0.140002
# X [s].8                                                          -0.078678
# Trigno sensor 3: EMG 3 [Volts]                                    0.018146
# X [s].9                                                          -0.078677
# Trigno sensor 3: ACC X 3 [g]                                      0.048699
# X [s].10                                                         -0.078677
# Trigno sensor 3: ACC Y 3 [g]                                      0.029307
# X [s].11                                                         -0.078677
# Trigno sensor 3: ACC Z 3 [g]                                     -0.077486
# X [s].12                                                         -0.078678
# Trigno sensor 4: EMG 4 [Volts]                                   -0.003053
# X [s].13                                                         -0.078677
# Trigno sensor 4: ACC X 4 [g]                                      0.070830
# X [s].14                                                         -0.078677
# Trigno sensor 4: ACC Y 4 [g]                                      0.003036
# X [s].15                                                         -0.078677
# Trigno sensor 4: ACC Z 4 [g]                                     -0.051868
# X [s].16                                                         -0.078678
# Trigno sensor 5: EMG 5 [Volts]                                    0.017293
# X [s].17                                                         -0.078677
# Trigno sensor 5: ACC X 5 [g]                                      0.263827
# X [s].18                                                         -0.078677
# Trigno sensor 5: ACC Y 5 [g]                                      0.192534
# X [s].19                                                         -0.078677
# Trigno sensor 5: ACC Z 5 [g]                                     -0.136612
# X [s].20                                                         -0.078678
# Trigno Mini sensor 8: EMG 8 [Volts]                               0.012988
# X [s].21                                                         -0.078677
# Trigno Mini sensor 8: ACC X 8 [g]                                -0.063766
# X [s].22                                                         -0.078677
# Trigno Mini sensor 8: ACC Y 8 [g]                                -0.158690
# X [s].23                                                         -0.078677
# Trigno Mini sensor 8: ACC Z 8 [g]                                 0.048322
# X [s].24                                                         -0.078678
# Trigno Mini sensor 10: EMG 10 [Volts]                            -0.000251
# X [s].25                                                         -0.078677
# Trigno Mini sensor 10: ACC X 10 [g]                               0.656425
# X [s].26                                                         -0.078677
# Trigno Mini sensor 10: ACC Y 10 [g]                               1.000000
# X [s].27                                                         -0.078677
# Trigno Mini sensor 10: ACC Z 10 [g]                               0.615393
#
#                                        X [s].27  \
# Trigno sensor 1: EMG 1 [Volts]        -0.001088
# X [s].1                                1.000000
# Trigno sensor 1: ACC X 1 [g]          -0.204892
# X [s].2                                1.000000
# Trigno sensor 1: ACC Y 1 [g]          -0.243707
# X [s].3                                1.000000
# Trigno sensor 1: ACC Z 1 [g]          -0.441000
# X [s].4                                1.000000
# Trigno sensor 2: EMG 2 [Volts]        -0.002950
# X [s].5                                1.000000
# Trigno sensor 2: ACC X 2 [g]          -0.153731
# X [s].6                                1.000000
# Trigno sensor 2: ACC Y 2 [g]           0.271238
# X [s].7                                1.000000
# Trigno sensor 2: ACC Z 2 [g]           0.003853
# X [s].8                                1.000000
# Trigno sensor 3: EMG 3 [Volts]         0.000869
# X [s].9                                1.000000
# Trigno sensor 3: ACC X 3 [g]           0.110666
# X [s].10                               1.000000
# Trigno sensor 3: ACC Y 3 [g]           0.145715
# X [s].11                               1.000000
# Trigno sensor 3: ACC Z 3 [g]           0.014134
# X [s].12                               1.000000
# Trigno sensor 4: EMG 4 [Volts]        -0.000228
# X [s].13                               1.000000
# Trigno sensor 4: ACC X 4 [g]           0.112469
# X [s].14                               1.000000
# Trigno sensor 4: ACC Y 4 [g]          -0.374951
# X [s].15                               1.000000
# Trigno sensor 4: ACC Z 4 [g]          -0.472347
# X [s].16                               1.000000
# Trigno sensor 5: EMG 5 [Volts]        -0.016504
# X [s].17                               1.000000
# Trigno sensor 5: ACC X 5 [g]           0.061628
# X [s].18                               1.000000
# Trigno sensor 5: ACC Y 5 [g]          -0.249026
# X [s].19                               1.000000
# Trigno sensor 5: ACC Z 5 [g]           0.109085
# X [s].20                               1.000000
# Trigno Mini sensor 8: EMG 8 [Volts]   -0.039364
# X [s].21                               1.000000
# Trigno Mini sensor 8: ACC X 8 [g]      0.241965
# X [s].22                               1.000000
# Trigno Mini sensor 8: ACC Y 8 [g]      0.402210
# X [s].23                               1.000000
# Trigno Mini sensor 8: ACC Z 8 [g]     -0.485816
# X [s].24                               1.000000
# Trigno Mini sensor 10: EMG 10 [Volts] -0.009773
# X [s].25                               1.000000
# Trigno Mini sensor 10: ACC X 10 [g]   -0.434475
# X [s].26                               1.000000
# Trigno Mini sensor 10: ACC Y 10 [g]   -0.078677
# X [s].27                               1.000000
# Trigno Mini sensor 10: ACC Z 10 [g]   -0.361014
#
#                                        Trigno Mini sensor 10: ACC Z 10 [g]
# Trigno sensor 1: EMG 1 [Volts]                                    0.000443
# X [s].1                                                          -0.361014
# Trigno sensor 1: ACC X 1 [g]                                      0.102325
# X [s].2                                                          -0.361014
# Trigno sensor 1: ACC Y 1 [g]                                      0.215604
# X [s].3                                                          -0.361014
# Trigno sensor 1: ACC Z 1 [g]                                      0.340382
# X [s].4                                                          -0.361014
# Trigno sensor 2: EMG 2 [Volts]                                    0.000245
# X [s].5                                                          -0.361014
# Trigno sensor 2: ACC X 2 [g]                                      0.089296
# X [s].6                                                          -0.361014
# Trigno sensor 2: ACC Y 2 [g]                                     -0.226025
# X [s].7                                                          -0.361014
# Trigno sensor 2: ACC Z 2 [g]                                     -0.039167
# X [s].8                                                          -0.361014
# Trigno sensor 3: EMG 3 [Volts]                                    0.003217
# X [s].9                                                          -0.361014
# Trigno sensor 3: ACC X 3 [g]                                     -0.144516
# X [s].10                                                         -0.361014
# Trigno sensor 3: ACC Y 3 [g]                                      0.166410
# X [s].11                                                         -0.361014
# Trigno sensor 3: ACC Z 3 [g]                                     -0.013671
# X [s].12                                                         -0.361014
# Trigno sensor 4: EMG 4 [Volts]                                    0.004665
# X [s].13                                                         -0.361014
# Trigno sensor 4: ACC X 4 [g]                                      0.129001
# X [s].14                                                         -0.361014
# Trigno sensor 4: ACC Y 4 [g]                                      0.024790
# X [s].15                                                         -0.361014
# Trigno sensor 4: ACC Z 4 [g]                                      0.135148
# X [s].16                                                         -0.361014
# Trigno sensor 5: EMG 5 [Volts]                                    0.005941
# X [s].17                                                         -0.361014
# Trigno sensor 5: ACC X 5 [g]                                      0.084284
# X [s].18                                                         -0.361014
# Trigno sensor 5: ACC Y 5 [g]                                      0.397733
# X [s].19                                                         -0.361014
# Trigno sensor 5: ACC Z 5 [g]                                     -0.075084
# X [s].20                                                         -0.361014
# Trigno Mini sensor 8: EMG 8 [Volts]                               0.001101
# X [s].21                                                         -0.361014
# Trigno Mini sensor 8: ACC X 8 [g]                                -0.003278
# X [s].22                                                         -0.361014
# Trigno Mini sensor 8: ACC Y 8 [g]                                -0.011757
# X [s].23                                                         -0.361014
# Trigno Mini sensor 8: ACC Z 8 [g]                                 0.020279
# X [s].24                                                         -0.361014
# Trigno Mini sensor 10: EMG 10 [Volts]                             0.003301
# X [s].25                                                         -0.361014
# Trigno Mini sensor 10: ACC X 10 [g]                               0.676629
# X [s].26                                                         -0.361014
# Trigno Mini sensor 10: ACC Y 10 [g]                               0.615393
# X [s].27                                                         -0.361014
# Trigno Mini sensor 10: ACC Z 10 [g]                               1.000000
#
# [55 rows x 55 columns]

# %%
df1.describe()
# Out:
#        Trigno sensor 1: EMG 1 [Volts]       X [s].1  \
# count                    2.318420e+05  17834.000000
# mean                    -8.241164e-07     60.186415
# std                      1.729252e-05     34.751570
# min                     -3.380480e-04      0.000000
# 25%                     -5.706870e-06     30.093200
# 50%                     -5.035480e-07     60.186400
# 75%                      4.531930e-06     90.279600
# max                      4.986800e-04    120.373000
#
#        Trigno sensor 1: ACC X 1 [g]       X [s].2  \
# count                  17834.000000  17834.000000
# mean                      -0.730139     60.186415
# std                        0.178343     34.751570
# min                       -1.498560      0.000000
# 25%                       -0.858045     30.093200
# 50%                       -0.781506     60.186400
# 75%                       -0.656626     90.279600
# max                        0.153078    120.373000
#
#        Trigno sensor 1: ACC Y 1 [g]       X [s].3  \
# count                  17834.000000  17834.000000
# mean                       0.043680     60.186415
# std                        0.355755     34.751570
# min                       -1.136000      0.000000
# 25%                       -0.048341     30.093200
# 50%                        0.132937     60.186400
# 75%                        0.314214     90.279600
# max                        0.600229    120.373000
#
#        Trigno sensor 1: ACC Z 1 [g]        X [s].4  \
# count                  17834.000000  231842.000000
# mean                      -0.089644      60.189490
# std                        0.203682      34.750643
# min                       -0.547860       0.000000
# 25%                       -0.269902      30.094725
# 50%                       -0.020142      60.189500
# 75%                        0.044312      90.284250
# max                        0.483406     120.379000
#
#        Trigno sensor 2: EMG 2 [Volts]       X [s].5  \
# count                   231842.000000  17834.000000
# mean                        -0.000010     60.186415
# std                          0.000009     34.751570
# min                         -0.000099      0.000000
# 25%                         -0.000014     30.093200
# 50%                         -0.000010     60.186400
# 75%                         -0.000005     90.279600
# max                          0.000109    120.373000
#
#                       ...                       X [s].23  \
# count                 ...                   17834.000000
# mean                  ...                      60.186415
# std                   ...                      34.751570
# min                   ...                       0.000000
# 25%                   ...                      30.093200
# 50%                   ...                      60.186400
# 75%                   ...                      90.279600
# max                   ...                     120.373000
#
#        Trigno Mini sensor 8: ACC Z 8 [g]       X [s].24  \
# count                       17834.000000  231842.000000
# mean                            0.344837      60.189490
# std                             0.182527      34.750643
# min                            -0.132937       0.000000
# 25%                             0.209476      30.094725
# 50%                             0.269902      60.189500
# 75%                             0.588144      90.284250
# max                             1.075580     120.379000
#
#        Trigno Mini sensor 10: EMG 10 [Volts]      X [s].25  \
# count                          231842.000000  17834.000000
# mean                               -0.000010     60.186415
# std                                 0.000005     34.751570
# min                                -0.000174      0.000000
# 25%                                -0.000012     30.093200
# 50%                                -0.000010     60.186400
# 75%                                -0.000008     90.279600
# max                                 0.000069    120.373000
#
#        Trigno Mini sensor 10: ACC X 10 [g]      X [s].26  \
# count                         17834.000000  17834.000000
# mean                             -0.234233     60.186415
# std                               0.140733     34.751570
# min                              -0.563973      0.000000
# 25%                              -0.310185     30.093200
# 50%                              -0.245731     60.186400
# 75%                              -0.193362     90.279600
# max                               0.829847    120.373000
#
#        Trigno Mini sensor 10: ACC Y 10 [g]      X [s].27  \
# count                         17834.000000  17834.000000
# mean                             -0.805590     60.186415
# std                               0.084485     34.751570
# min                              -1.023210      0.000000
# 25%                              -0.841932     30.093200
# 50%                              -0.817761     60.186400
# 75%                              -0.797620     90.279600
# max                               0.000000    120.373000
#
#        Trigno Mini sensor 10: ACC Z 10 [g]
# count                         17834.000000
# mean                             -0.073456
# std                               0.102295
# min                              -0.265873
# 25%                              -0.149050
# 50%                              -0.092653
# 75%                              -0.008057
# max                               0.382696
#
# [8 rows x 55 columns]
